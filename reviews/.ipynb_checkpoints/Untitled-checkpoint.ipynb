# %%
# импорт библиотек
import requests, sys, webbrowser, bs4

# Указываем сайт и заголовки чтобы нас не выбросило с ошибкой 403
url = 'https://www.dns-shop.ru/product/3c49619e66c43120/120-gb-ssd-nakopitel-siliconpower-velox-v55-sp120gbss3v55s25/opinion/'
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}

# Запрос
res = requests.get(url, headers=headers)

# Закидываем страницу в парсер
soup = bs4.BeautifulSoup(res.text, 'html5lib')

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(open("C:\\example.html"), "html.parser")

for city in soup.find_all('span', {'class' : 'city-sh'}):
    print(city)

# %%
opinions_html = soup.findAll('div', {'class': 'ow-opinion__texts'})
opinions = []
for opinion_texts in opinions_html:
    opinion = ""
    # Каждый отзыв состоит из нескольких секций, секция состоит из заголовка и описания
    for opinion_section in opinion_texts.contents:
        if ((opinion_section != ' ') and not ("Фотографии" in opinion_section.contents[1])):
            opinion += '{' + opinion_section.contents[1].text + '}: ' + opinion_section.contents[3].text + "\n"
    opinions.append(opinion)

# %%
import csv
with open(..., 'w', newline='') as myfile:
     wr = csv.writer(myfile, quoting=csv.QUOTE_ALL)
     wr.writerow(mylist)

# %%
for opinion in opinions:
    print(opinion)
# Out:
# {Достоинства}: {{Достоинства}}
# {Недостатки}: {{Недостатки}}
# {Комментарий}: {{Комментарий}}
#
# {Достоинства}: Быстрый, надёжный, недорогой, не особо теряет в скорости если компьютер не умеет Trim (скажем под вистой или XP), гарантия 3 года.
# {Недостатки}: Не самый быстрый (но и далеко не самый медленный) SSD из существующих, характеристики несколько разнятся от партии к партии.
# {Комментарий}: Моя Win7 со всем хламом вроде антивируса, фаервола и ещё десятка-другого представителей разномастного софта грузится за 30-40с и выключается за 10-15с.\r\nВобще довольно странно что данная модель не пользуется популярностью.\r\nДля такой цены у диска просто шикарные скоростные характеристики уступающие только лидерам рынка вроде Plextor, способность без особых проблем жить под WinXP и общая неприхотливость.\r\nИзначальный производитель диска - Phison и данная модель продаётся под разными именами.\r\nSilicon Power я взял из за сочетания низкой цены и 3х летней гарантии.
#
# {Достоинства}: Я покупал такойже Диск в 2012 году? Идосих пор работает. Закажу себе ещё один сбольшим обьёмом.
#
# {Достоинства}: Быстрее HDD
# {Недостатки}: Сдох, а на нем была очень нужная инфа
# {Комментарий}: В общем, работал нормально в целом около 2 лет, при очень низкой нагрузке. Потом мне ноут понадобился и я его нагрузил . Пара месяцев и все, бобик сдох вместе с очень нужной инфой. Не видится системой. Похоже на контроллер питания...
#
# {Достоинства}: CCД со всеми вытекающими
# {Недостатки}: Недолговечный
# {Комментарий}: Прожил полтора года и помер. Использовался как второй диск, т.е. в чтении\записи учавствовал мало. Вернул бы по гарантии, если бы не потерял доки и коробку. За всю серии сказать не могу, возможно мне так "повезло" с экземпляром.
#
# {Достоинства}: Диск как диск
# {Недостатки}: Через 2,5 года использования начал играть со мной в игру "Попробуй найти меня в BIOSе". То есть комп не видит его в списке доступных дисков и зависает на этапе загрузить ОС. Начинку другую я перепроверил, другие имеющиеся ssd работают штатно. Результаты CrystalDiskInfo пациента опасений не вызывали. Отсюда вывод - накрывается контроллер.
# {Комментарий}: Пожалуй на замену возьму что-нибудь КРОМЕ ssd от SiliconPower
#
# {Достоинства}: -цена (брал за 2790 в мае 2014). На тот момент был неплохой вариант. Сегодня считаю есть более актуальные решения;-хорошая скорость для своей ценовой категории.-Качество, что называется "по документам".
# {Недостатки}: -стал тормозить спустя 5 лет активного использования, можно сказать свое отработал.
#
# {Достоинства}: Скорость заявленная соответствует. Простота настройки.
# {Недостатки}: Юзал на компе для инет серфинга 3 года и один месяц.Сдох внезапно. Перестал определяться. СМАРТ показывал хорошие значения за неделю до смерти.
# {Комментарий}: По опыту уже могу сказать, что лучше разориться и взять получше. Тип памяти здесь уже устарел.
#
# {Достоинства}: Быстрее чем с hdd
# {Недостатки}: скончался внезапно не прожив и года; проблема с драйверами, пока не обновила биос, не переставила на нем ос, система не видела и видеть не хотела
# {Комментарий}: не рекомендую
#
# {Достоинства}: Не дорогой, 3 месяца - полёт нормальный.
# {Недостатки}: Отсутствие софтинки для переноса системы.Пришлось похимичить при переносе .
#
# {Достоинства}: Цена
# {Недостатки}: Умер через 2 месяца
# {Комментарий}: Не рекомендую к покупке
#
# {Достоинства}: Высокая скорость чтения и загрузки винды.Красивый внешний вид
# {Недостатки}: Вообще не заметил..
# {Комментарий}: После того как включил винду на нём ,наступил оргазм.Диск очень добротный ,потрясающая сборка.С учётом того что ssd купил первый раз
